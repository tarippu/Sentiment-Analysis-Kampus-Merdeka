# %% [markdown]
# # Import Library

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream 
import pandas as pd
import csv

# %% [markdown]
# # Akses code untuk API twitter

# %%
consumer_key = 'KMgkMF1bILX3wJZRzzO6q6ME1'
consumer_secret = '1IYTzqcepnu99L2K8gyRhwBinKqbwgvk1i0tjFTgDnrZgVFUy6'
access_token = '1527877389207752704-iTnPyf83kf3MX6QPPe3CvIAbw1elCa'
access_token_secret = 'n0pZZfVPKkEuz9TwCXLyVFQBT9Y01QEgM1L1601UzHalY'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
search_key = "KampusMerdeka"

# %% [markdown]
# # Mengambil data twitter

# %%
csvFile = open(search_key+"1.csv","a+", newline="", encoding="utf-8")
csvWriter = csv.writer(csvFile)
c = []
i = []
u = []
t = []

for tweet in tweepy.Cursor(api.search_tweets,q=search_key + " -filter:retweets",count=1000,lang="id", until="2022-06-13").items(1000):
  print(tweet.created_at, tweet.id, tweet.user.name, tweet.text)
  c.append(tweet.created_at)
  i.append(tweet.id)
  u.append(tweet.user.name)
  t.append(tweet.text.encode("utf-8"))
  tweets = [tweet.created_at, tweet.id, tweet.user.name, tweet.text.encode("utf-8")]
  csvWriter.writerow(tweets)

dictTweets = {"waktu":c, "id":i, "username":u, "teks":t}
df = pd.DataFrame(dictTweets, columns=["Waktu", "id", "username", "teks"])
df
# Out:
# 2022-06-12 14:46:13+00:00 1535996903317311488 Fakultas Teknik UNIPA Surabaya .
# Berikut keseruan pada saat workshop OBE di Trawas dilakukan mahasiswa dan dosen antusias mengikuti acara tersebut… https://t.co/WvD4Uncu4E
# 2022-06-12 12:07:23+00:00 1535956930111602688 IPB #IPBPedia
# Hai, #IPBnesian!
#
# Yuk kita simak informasi terkait penyakit mulut dan kuku (PMK) pada hewan ternak seleng… https://t.co/epYaEmPece
# 2022-06-12 10:57:54+00:00 1535939443013476352 Universitas Darma Agung tetapi masyarakat juga bersama jajaran pemerintah desa dan kelurahan sangat mendukung gerakan Pencegahan Penyalahgu… https://t.co/7J1yduX8qF
# 2022-06-12 08:57:37+00:00 1535909174831329281 Universitas Negeri Padang UNP Keluar sebagai Juara Umum POMProv Sumbar 2022 https://t.co/x2GoPRAgOq
# #universitasnegeripadang
# #humasunp… https://t.co/0DyPYkaCXk
# 2022-06-12 07:19:11+00:00 1535884401363390464 Mohamad Zainudin Pentingnya komunikasi Dalam Kehidupan Kampus 🙄
# .
# .
# .
# Info pendaftaran kuliah :
# ...

# %%
df = pd.read_csv('kampusmerdeka.csv')
df.head(5)

# %%
print(df.shape)
print(df.columns)
